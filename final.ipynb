# %%
import pandas as pd

df = pd.read_csv("")
# Out:
# Index(['date', 'client', 'volunteer', 'pantry'], dtype='object')
# ['Gardens (Food Pantry)' "Tabitha's (Spanish Fork)"
#  "Tabitha's (American Fork)" 'UFB Program' 'CSFP Program' 'Gardens' 'CSFP'
#  'UFB' nan 'TSF' 'TAF' 'PG' 'SF'
#  'Physical limitations, needs food to be dropped off on kitchen counter'
#  'Call/text upon arrival' 'EG' 'AC' 'MC' 'CR' 'MC`']
# 1
