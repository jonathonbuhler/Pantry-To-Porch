# %%
import pandas as pd

df = pd.read_csv("allyears.csv")

df["client"].unique()
# Out:
# array(['Gardens (Food Pantry)', "Tabitha's (Spanish Fork)",
#        "Tabitha's (American Fork)", 'UFB Program', 'CSFP Program',
#        'Gardens', 'CSFP', 'UFB', nan, 'TSF', 'TAF', 'PG', 'SF',
#        'Physical limitations, needs food to be dropped off on kitchen counter',
#        'Call/text upon arrival', 'EG', 'AC', 'MC', 'CR', 'MC`'],
#       dtype=object)
